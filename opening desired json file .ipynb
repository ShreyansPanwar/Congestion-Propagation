# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
conda install geopandas
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
conda update -n base -c defaults conda
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working...
# ...
#   - defaults/win-64::dask-2022.7.0-py38haa95532_0, defaults/win-64::dask-core-2022.7.0-py38haa95532_0, defaults/win-64::distributed-2022.7.0-py38haa95532_0, defaults/win-64::jupyter_client-7.3.4-py38haa95532_0, defaults/win-64::tornado-6.1-py38h2bbff1b_0
#   - defaults/win-64::dask-2022.5.0-py38haa95532_0, defaults/win-64::dask-core-2022.5.0-py38haa95532_0, defaults/win-64::distributed-2022.5.0-py38haa95532_0, defaults/win-64::jupyter_client-7.4.8-py38haa95532_0, defaults/win-64::tornado-6.2-py38h2bbff1b_0done
#
# ## Package Plan ##
#
#   environment location: C:\Users\shrey\anaconda3
#
#
#   added / updated specs:
# DEBUG menuinst_win32:__init__(198): Menu: name: 'Anaconda${PY_VER} ${PLATFORM}', prefix: 'C:\Users\shrey\anaconda3', env_name: 'None', mode: 'user', used_mode: 'user'
# ...

# %%
f = open('C:/Users/shrey/Downloads/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/07-47-11.json', "r")
  
# Reading from file
speed_data1 = json.loads(f.read())

# %%
k = open('/home/jovyan/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/07-47-11.json', "r")
  
# Reading from file
data1 = json.loads(k.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b1a5c0243932> in <module>
# ----> 1 k = open('/home/jovyan/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/07-47-11.json', "r")
#       2
#       3 # Reading from file
#       4 data1 = json.loads(k.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/07-47-11.json'

# %%
# f = open ('/home/jovyan/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/23-59-02.json', "r")
  
# # Reading from file
# # speed_data = json.loads(f.read())
# C:\Users\shrey\OneDrive - Nanyang Technological University\1 august data\speed-2022-08-01

# %%
len(speed_data1)

# %%
Files = []

Files = os.listdir('C:/Users/shrey/Downloads/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand')

# %%
Files

# %%
k = []
k = os.listdir('/home/jovyan/LTA/')
print(k)

# %%
for i in range(len(Files)):
    path = 'LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/'  + Files[i] + '' 
    h = open(path, "r")
    s1 = json.loads(h.read())

# %%
s1

# %%
path = '/home/jovyan/LTA/NTU_congestion_project/Data_examples/LTA_DataMall_SpeedBand/speed-2022-08-01/'  + Files[0] + ''

# %%
path
